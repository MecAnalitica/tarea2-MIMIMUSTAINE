# %%
import numpy as np
import math
from scipy.integrate import odeint
from matplotlib import pyplot as plt
from matplotlib import style

#Valor asignado a variables
N = 20
r = [1.0, 2.0, 3.0, 4.0]
U = [0.2, 0.4, 0.7, 0.9]
V = [[] for x in range(4)]

for i in range(len(U)):
    for j in range(N):
        V[i].append(U[i] * r[0] * (1 - U[i]))
        U[i] = V[i][j]
        
U = [0.2, 0.4, 0.7, 0.9]
#Figuras
plt.figure(figsize=(25,5))
for i in range(len(V)):
    plt.plot(np.linspace(0, N, N),V[i],'o-',label='$U = {0}$'.format(U[i]))
plt.title('Población anual para $r = {0}$'.format(r[0]))
plt.ylabel('Relación entre población existente y la máxima posible $(U_{n+1})$')
plt.xlabel('Población anual para $r = {0}$'.format(r[0]))
plt.legend()
plt.grid(True,color='slategray')
plt.show()

U = [0.2, 0.4, 0.7, 0.9]
V = [[] for x in range(4)]

for i in range(len(U)):
    for j in range(N):
        V[i].append(U[i] * r[1] * (1 - U[i]))
        U[i] = V[i][j]
        
U = [0.2, 0.4, 0.7, 0.9]
#Figuras
plt.figure(figsize=(25,5))
for i in range(len(V)):
    plt.plot(np.linspace(0, N, N),V[i],'o-',label='$U = {0}$'.format(U[i]))
plt.title('Población anual para $r = {0}$'.format(r[1]))
plt.ylabel('Relación entre población existente y la máxima posible $(U_{n+1})$')
plt.xlabel('Población anual para $r = {0}$'.format(r[1]))
plt.legend()
plt.grid(True,color='slategray')
plt.show()

U = [0.2, 0.4, 0.7, 0.9]
V = [[] for x in range(4)]

for i in range(len(U)):
    for j in range(N):
        V[i].append(U[i] * r[2] * (1 - U[i]))
        U[i] = V[i][j]
        
U = [0.2, 0.4, 0.7, 0.9]
#Figuras
plt.figure(figsize=(25,5))
for i in range(len(V)):
    plt.plot(np.linspace(0, N, N),V[i],'o-',label='$U = {0}$'.format(U[i]))
plt.title('Población anual para $r = {0}$'.format(r[2]))
plt.ylabel('Relación entre población existente y la máxima posible $(U_{n+1})$')
plt.xlabel('Población anual para $r = {0}$'.format(r[2]))
plt.legend()
plt.grid(True,color='slategray')
plt.show()

U = [0.2, 0.4, 0.7, 0.9]
V = [[] for x in range(4)]
Ug = [[] for x in range(4)]

for i in range(len(U)):
    for j in range(N):
        V[i].append(U[i] * r[3] * (1 - U[i]))
        U[i] = V[i][j]
        
U = [0.2, 0.4, 0.7, 0.9]
#Figuras
plt.figure(figsize=(25,5))
for i in range(len(V)):
    plt.plot(np.linspace(0, N, N),V[i],'o-',label='$U = {0}$'.format(U[i]))
plt.title('Población anual para $r = {0}$'.format(r[3]))
plt.ylabel('Relación entre población existente y la máxima posible $(U_{n+1})$')
plt.xlabel('Población anual para $r = {0}$'.format(r[3]))
plt.legend()
plt.grid(True,color='slategray')
plt.show()

# %%
#Para observar los cíclos límite.

# %%
from pylab import show, scatter, xlim, ylim
from random import randint

iter = 1000         # Number of iterations per point
seed = 0.5          # Seed value for x in (0, 1)
spacing = .0001     # Spacing between points on domain (r-axis)
res = 8             # Largest n-cycle visible

# Initialize r and x lists
rlist = []
xlist = []

def logisticmap(x, r):

    return x * r * (1 - x)

# Return nth iteration of logisticmap(x. r)
def iterate(n, x, r):

    for i in range(1,n):
        x = logisticmap(x, r)

    return x

# Generate list values -- iterate for each value of r
for r in [i * spacing for i in range(int(1/spacing),int(4/spacing))]:
   rlist.append(r) 
   xlist.append(iterate(randint(iter-res/2,iter+res/2), seed, r))

scatter(rlist, xlist, s = .01)
xlim(0.9, 4.1)
ylim(-0.1,1.1)
show()
